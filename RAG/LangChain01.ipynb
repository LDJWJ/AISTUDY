# %% [markdown]
# # 1. WebBaseLoaderm
#  * WebBaseLoader**는 URL로부터 HTML 페이지의 모든 text를 load합니다.

# %% [markdown]
# - LangChain은 웹에 기록된 글도 텍스트 형식으로 가져와 LLM에 활용할 수 있습니다. 대표적인 URL Loader는 WebBaseLoader와 UnstructuredURLLoader가 있습니다.

# %%
from langchain.document_loaders import WebBaseLoader

loader = WebBaseLoader("https://www.espn.com/")
data = loader.load()
data
# Out:
# [Document(page_content="\n\n\n\n\n\n\n\n\nESPN - Serving Sports Fans. Anytime. Anywhere.\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n        Skip to main content\n    \n\n        Skip to navigation\n    \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n<\n\n>\n\n\n\n\n\n\n\n\n\nMenuESPN\n\n\n\n\n\nscores\n\n\n\nNFLNCAAFNBANHLMLBSoccer…NCAAMNCAAWSports BettingBoxingCFLNCAACricketF1GolfHorseLLWSMMANASCARNBA G LeagueOlympic SportsPLLRacingRN BBRN FBRugbyTennisWNBAAEWProfessional WrestlingWWEX GamesXFLMore ESPNFantasyWatchESPN BETESPN+\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n  \n\nSubscribe Now\n\n\n\n\n\nFA Cup: Round 4\n\n\n\n\n\n\n\nLALIGA\n\n\n\n\n\n\n\nBundesliga\n\n\n\n\n\n\n\nNCAA Men's Basketball\n\n\n\n\n\n\n\nNCAA Women's Basketball\n\n\n\n\n\n\n\nNHL\n\n\n\n\n\n\n\nNFL PrimeTime\n\n\nQuick Links\n\n\n\n\nSuper Bowl LVIII\n\n\n\
# ...

# %%
### 다른 URL 가져오기
loader = WebBaseLoader("https://ko.wikipedia.org/wiki/%EB%8C%80%ED%98%95_%EC%96%B8%EC%96%B4_%EB%AA%A8%EB%8D%B8")
data = loader.load()
data
# Out:
# [Document(page_content='\n\n\n\n대형 언어 모델 - 위키백과, 우리 모두의 백과사전\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n본문으로 이동\n\n\n\n\n\n\n\n주 메뉴\n\n\n\n\n\n주 메뉴\n사이드바로 이동\n숨기기\n\n\n\n\t\t둘러보기\n\t\n\n\n대문최근 바뀜요즘 화제임의의 문서로기부\n\n\n\n\n\n\t\t사용자 모임\n\t\n\n\n사랑방사용자 모임관리 요청\n\n\n\n\n\n\t\t편집 안내\n\t\n\n\n도움말정책과 지침질문방\n\n\n\n\n\n언어\n\n이 위키백과에서 언어 링크는 문서 제목 건너편의 문서 최상단에 있습니다. 최상단으로 이동합니다.\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n검색\n\n\n\n\n\n\n\n\n\n\n\n검색\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n계정 만들기\n\n로그인\n\n\n\n\n\n\n\n\n개인 도구\n\n\n\n\n\n 계정 만들기 로그인\n\n\n\n\n\n\t\t로그아웃한 편집자를 위한 문서 더 알아보기\n\n\n\n기여토론\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n목차\n사이드바로 이동\n숨기기\n\n\n\n\n처음 위치\n\n\n\n\n\n1대형 언어 모델 목록\n\n\n\n\n\n\n\n2각주\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n목차 토글\n\n\n\n\n\n\n\n대형 언어 모델\n\n\n\n31개 언어\n\n\n\n\nالعربيةAzərbaycancaBoarischBosanskiCatalàČeštinaDeutschΕλληνικάEnglishEspañolEuskaraفارسیFrançaisGalegoעבריתहिन्दीBahasa IndonesiaItaliano日本語МакедонскиPortug
# ...

# %% [markdown]
# ### Streamlit st.write 페이지 가져오기

# %%
### Streamlit 페이지 가져와 보기
# https://docs.streamlit.io/library/api-reference/write-magic/st.write
loader = WebBaseLoader("https://docs.streamlit.io/library/api-reference/write-magic/st.write")
data = loader.load()
data
# Out:
# [Document(page_content='st.write - Streamlit DocsDocumentationsearchSearchrocket_launchGet startedInstallationaddFundamentalsaddTutorialsadddescriptionStreamlit libraryAPI referenceremoveWrite and magicremovest.writemagicText elementsaddData elementsaddChart elementsaddInput widgetsaddMedia elementsaddLayouts and containersaddChat elementsaddStatus elementsaddControl flowaddUtilitiesaddMutate chartsState managementPerformanceaddPersonalizationaddConnections and databasesaddApp testingaddAdvanced featuresaddComponentsaddRoadmapopen_in_newChangelogCheat sheetcloudStreamlit Community CloudGet startedaddDeploy your appaddManage your appaddShare your appaddManage your accountaddTroubleshootingschoolKnowledge baseTutorialsaddUsing StreamlitStreamlit ComponentsInstalling dependenciesDeployment issuesHome/Streamlit library/API reference/Write and magic/st.writest.writeStreamlit VersionVersion 1.30.0Version 1.29.0Version 1.28.0Version 1.27.0Version 1.26.0Version 1.25.0Version 1.24.0Version 1.
# ...

# %% [markdown]
# ### Stremalit 여러 링크 내용 다운로드

# %%
### 몇개의 Streamlit link 데이터를 다운로드 받기.
links = [ 'https://docs.streamlit.io/library/api-reference/write-magic/st.write',
          'https://docs.streamlit.io/library/api-reference/write-magic/magic' ]


for link in links:
  loader = WebBaseLoader(link)
  data = loader.load()
  content = data[0].page_content
  print( len(content) )
  print( content[0:500] )
# Out:
# 4529
# st.write - Streamlit DocsDocumentationsearchSearchrocket_launchGet startedInstallationaddFundamentalsaddTutorialsadddescriptionStreamlit libraryAPI referenceremoveWrite and magicremovest.writemagicText elementsaddData elementsaddChart elementsaddInput widgetsaddMedia elementsaddLayouts and containersaddChat elementsaddStatus elementsaddControl flowaddUtilitiesaddMutate chartsState managementPerformanceaddPersonalizationaddConnections and databasesaddApp testingaddAdvanced featuresaddComponentsad
# 2582
# ...

# %% [markdown]
# ### 텍스트로 이를 저장하기

# %%
### 몇개의 Streamlit link 데이터를 다운로드 받기.
links = [ 'https://docs.streamlit.io/library/api-reference/write-magic/st.write',
          'https://docs.streamlit.io/library/api-reference/write-magic/magic' ]


for link in links:
  loader = WebBaseLoader(link)
  data = loader.load()
  content = data[0].page_content
  print( len(content) )
  # 파일명을 링크의 일부를 기반으로 생성
  file_name = link.split('/')[-1] + '.txt'
  # 웹페이지 데이터를 파일로 저장
  with open(file_name, 'w', encoding='utf-8') as file:
    file.write(content)
  print(f'페이지 내용을 {file_name} 파일로 저장했습니다.')
# Out:
# 4529
# 페이지 내용을 st.write.txt 파일로 저장했습니다.
# 2582
# 페이지 내용을 magic.txt 파일로 저장했습니다.

# %%
import os

### 몇개의 Streamlit link 데이터를 다운로드 받기.
links = [ 'https://docs.streamlit.io/library/api-reference/write-magic/st.write',
          'https://docs.streamlit.io/library/api-reference/write-magic/magic' ]


# 데이터를 저장할 폴더 생성 (이미 존재하면 무시)
data_folder = 'data'
if not os.path.exists('data'):
    os.mkdir('data')

# 각 링크의 데이터를 다운로드하고 파일로 저장
for index, link in enumerate(links, start=1):
  loader = WebBaseLoader(link)
  data = loader.load()
  content = data[0].page_content
  print( len(content) )
  # 파일명을 링크의 일부를 기반으로 생성
  file_name = f"{data_folder}/{index}_" + link.split('/')[-1] + ".txt"
  # 웹페이지 데이터를 파일로 저장
  with open(file_name, 'w', encoding='utf-8') as file:
    file.write(content)
  print(f'페이지 내용을 {file_name} 파일로 저장했습니다.')
# Out:
# 4529
# 페이지 내용을 data/1_st.write.txt 파일로 저장했습니다.
# 2582
# 페이지 내용을 data/2_magic.txt 파일로 저장했습니다.

# %%
### 판다스를 이용하여 링크를 가져와 이를 이용하여 결과를 만들어낸다.
import os
import pandas as pd

# CSV 파일 경로
file_path = "result_2024012914.xlsx"

# CSV 파일 읽기
df = pd.read_excel(file_path)

links = df['Link'].to_list()

# 각 링크의 데이터를 다운로드하고 파일로 저장
for index, link in enumerate(links, start=1):
  print(link)
# Out:
# https://docs.streamlit.io/library/api-reference/write-magic/st.write
# https://docs.streamlit.io/library/api-reference/write-magic/magic
# https://docs.streamlit.io/library/api-reference/text/st.markdown
# https://docs.streamlit.io/library/api-reference/text/st.title
# https://docs.streamlit.io/library/api-reference/text/st.header
# https://docs.streamlit.io/library/api-reference/text/st.subheader
# https://docs.streamlit.io/library/api-reference/text/st.caption
# https://docs.streamlit.io/library/api-reference/text/st.code
# https://docs.streamlit.io/library/api-reference/text/st.text
# https://docs.streamlit.io/library/api-reference/text/st.latex
# https://docs.streamlit.io/library/api-reference/text/st.divider
# https://docs.streamlit.io/library/api-reference/data/st.dataframe
# https://docs.streamlit.io/library/api-reference/data/st.data_editor
# https://docs.streamlit.io/library/api-reference/data/st.column_config
# https://docs.streamlit.io/library/api-reference/data/st.table
# ...

# %% [markdown]
# ### 링크를 가져와, 이를 이용하여 결과를 만들어낸다.

# %%
### 판다스를 이용하여 링크를 가져와 이를 이용하여 결과를 만들어낸다.
import os
import pandas as pd

# CSV 파일 경로
file_path = 'result_2024012914.xlsx'

# CSV 파일 읽기
df = pd.read_excel(file_path)
foldername = input("데이터저장 폴더는:")

# 데이터를 저장할 폴더 생성 (이미 존재하면 무시)
data_folder = foldername
if not os.path.exists(data_folder):
    os.mkdir(data_folder)

links = df['Link'].to_list()

# 각 링크의 데이터를 다운로드하고 파일로 저장
for index, link in enumerate(links, start=1):
  loader = WebBaseLoader(link)
  data = loader.load()
  content = data[0].page_content
  print( len(content) )
  # 파일명을 링크의 일부를 기반으로 생성
  file_name = f"{data_folder}/{index}_" + link.split('/')[-1] + ".txt"
  # 웹페이지 데이터를 파일로 저장
  with open(file_name, 'w', encoding='utf-8') as file:
    file.write(content)
  print(f'페이지 내용을 {file_name} 파일로 저장했습니다.')
# Out:
# 4529
# 페이지 내용을 data2401/1_st.write.txt 파일로 저장했습니다.
# 2582
# 페이지 내용을 data2401/2_magic.txt 파일로 저장했습니다.
# 3546
# 페이지 내용을 data2401/3_st.markdown.txt 파일로 저장했습니다.
# 2741
# 페이지 내용을 data2401/4_st.title.txt 파일로 저장했습니다.
# 3166
# 페이지 내용을 data2401/5_st.header.txt 파일로 저장했습니다.
# 3192
# 페이지 내용을 data2401/6_st.subheader.txt 파일로 저장했습니다.
# 3045
# 페이지 내용을 data2401/7_st.caption.txt 파일로 저장했습니다.
# 2259
# 페이지 내용을 data2401/8_st.code.txt 파일로 저장했습니다.
# 1780
# 페이지 내용을 data2401/9_st.text.txt 파일로 저장했습니다.
# 2135
# 페이지 내용을 data2401/10_st.latex.txt 파일로 저장했습니다.
# 2068
# 페이지 내용을 data2401/11_st.divider.txt 파일로 저장했습니다.
# 6964
# 페이지 내용을 data2401/12_st.dataframe.txt 파일로 저장했습니다.
# 8662
# 페이지 내용을 data2401/13_st.data_editor.txt 파일로 저장했습니다.
# 3625
# 페이지 내용을 data2401/14_st.column_config.txt 파일로 저장했습니다.
# 2345
# 페이지 내용을 data2401/15_st.table.txt 파일로 저장했습니다.
# 4540
# 페이지 내용을 data2401/16_st.metric.txt 파일로 저장했습니다.
# 2180
# 페이지 내용을 data2401/17_st.json.txt 파일로 저장했습니다.
# 5740
# 페이지 내용을 data2401/18_st.area_chart.txt 파일로 저장했습니다.
# 5757
# ...

# %%
### 구글드라이브로 생성된 폴더를 옮기기
# from google.colab import drive
# drive.mount('/content/drive')

# %% [markdown]
# ## 파일 복사

# %%
import shutil
import os

# 원본 폴더와 대상 폴더 경로 설정
source_folder = 'D:\Github\AISTUDY\RAG\data2401'
target_folder1 = 'D:\Github\AISTUDY\RAG\data2401_copy'

# print(os.listdir(target_folder1))

# 원본 폴더의 내용을 대상 폴더로 복사
# try:
shutil.copytree(source_folder, target_folder1)
print(f'{source_folder}의 내용이 {target_folder1}로 복사되었습니다.')
# except FileExistsError:
#     print(f'{target_folder}에 이미 동일한 이름의 폴더 또는 파일이 있습니다.')
# except Exception as e:
#     print(f'오류가 발생하였습니다: {str(e)}')
# Out:
# D:\Github\AISTUDY\RAG\data2401의 내용이 D:\Github\AISTUDY\RAG\data2401_copy로 복사되었습니다.

# %% [markdown]
# ### OpenAI 초기 인증

# %%
import os
from openai import OpenAI

def init_api():
    with open("chatgpt.env") as env:
       for line in env:
           key, value = line.strip().split("=")
           os.environ[key] = value

init_api()
client = OpenAI(api_key  = os.environ.get("API_KEY"))

# %% [markdown]
# ### ChatGPT로 수행

# %%
## data 폴더의 파일의 모든 내용을 불러와 이를 출력하기
import os
import time

# 데이터를 불러올 폴더 설정
data_folder = 'data2401'

# 폴더 내의 모든 파일 목록을 가져옵니다.
file_list = os.listdir(data_folder)

# 각 파일에 대해
for file_name in file_list:
    file_path = os.path.join(data_folder, file_name)  # 파일의 전체 경로 생성

    # 파일인지 확인하고, 파일이면 내용을 읽어 출력합니다.
    print(file_path)
# Out:
# data2401\10_st.latex.txt
# data2401\11_st.divider.txt
# data2401\12_st.dataframe.txt
# data2401\13_st.data_editor.txt
# data2401\14_st.column_config.txt
# data2401\15_st.table.txt
# data2401\16_st.metric.txt
# data2401\17_st.json.txt
# data2401\18_st.area_chart.txt
# data2401\19_st.bar_chart.txt
# data2401\1_st.write.txt
# data2401\20_st.line_chart.txt
# data2401\21_st.scatter_chart.txt
# data2401\22_st.map.txt
# data2401\23_st.pyplot.txt
# data2401\24_st.altair_chart.txt
# data2401\25_st.vega_lite_chart.txt
# data2401\26_st.plotly_chart.txt
# data2401\27_st.bokeh_chart.txt
# data2401\28_st.pydeck_chart.txt
# data2401\29_st.graphviz_chart.txt
# data2401\2_magic.txt
# data2401\30_st.button.txt
# data2401\31_st.download_button.txt
# data2401\32_st.link_button.txt
# data2401\33_st.checkbox.txt
# data2401\34_st.toggle.txt
# data2401\35_st.radio.txt
# data2401\36_st.selectbox.txt
# data2401\37_st.multiselect.txt
# data2401\38_st.slider.txt
# data2401\39_st.select_slider.txt
# ...

# %%
## data 폴더의 파일의 모든 내용을 불러와 이를 출력하기
import os
import time

# 데이터를 불러올 폴더 설정
data_folder = 'data2401'

# 폴더 내의 모든 파일 목록을 가져옵니다.
file_list = os.listdir(data_folder)

# 각 파일에 대해
for file_name in file_list:
    file_path = os.path.join(data_folder, file_name)  # 파일의 전체 경로 생성

    # 파일인지 확인하고, 파일이면 내용을 읽어 출력합니다.
    if os.path.isfile(file_path):
        with open(file_path, 'r', encoding='utf-8') as file:
            content = file.read()
            print(f'File: {file_name}\nContent:\n{content}\n{"=" * 20}\n')
            print()
# Out:
# File: 10_st.latex.txt
# Content:
# ...

# %%
## data 폴더의 파일의 모든 내용을 불러와 이를 출력하기
import os
import time

# 데이터를 저장할 폴더 설정
data_folder = 'data2401'

# 폴더 내의 모든 파일 목록을 가져옵니다.
file_list = os.listdir(data_folder)

# 각 파일에 대해
for file_name in file_list:
    file_path = os.path.join(data_folder, file_name)  # 파일의 전체 경로 생성

    # 파일인지 확인하고, 파일이면 내용을 읽어 출력합니다.
    if os.path.isfile(file_path):
        with open(file_path, 'r', encoding='utf-8') as file:
            content = file.read()
            # print(f'File: {file_name}\nContent:\n{content}\n{"=" * 20}\n')

            next = client.chat.completions.create(
                    model="gpt-3.5-turbo-16k",
                    messages=[
                      {
                        "role": "system",
                        "content": "Streamlit IT 가이드 설명 웹 페이지 내용인데, 이 내용을 1000자 이내로 요약을 부탁해."
                      },
                      {
                        "role": "user",
                        "content": content
                      }
                    ],
                    temperature=0,
                    max_tokens=1200,
                    top_p=1,
                    frequency_penalty=0,
                    presence_penalty=0
                  )

            print(f'File: {file_name}' + next.choices[0].message.content)
    time.sleep(5)
# Out:
# File: 10_st.latex.txtThe st.latex function in the Streamlit library allows you to display mathematical expressions formatted as LaTeX. You can pass a string or a SymPy expression as the "body" parameter, and it will be rendered as LaTeX. It is recommended to use raw Python strings when passing a string to ensure proper rendering of backslashes. Additionally, you can provide an optional "help" parameter to display a tooltip next to the LaTeX expression. The st.latex function supports various LaTeX functions, and you can find a list of supported functions at the provided link.
# ...

# %% [markdown]
# ## 파일로 만들기

# %%
## data 폴더의 파일의 모든 내용을 불러와 이를 출력하기
import os
import time
import pandas as pd

# 데이터를 저장할 폴더 설정
data_folder = 'data2401'

# 폴더 내의 모든 파일 목록을 가져옵니다.
file_list = os.listdir(data_folder)

# 결과를 저장할 빈 DataFrame을 생성합니다.
df_results = pd.DataFrame(columns=['file_name', 'summary'])

# 각 파일에 대해
for file_name in file_list:
    file_path = os.path.join(data_folder, file_name)  # 파일의 전체 경로 생성

    # 파일인지 확인하고, 파일이면 내용을 읽어 출력합니다.
    if os.path.isfile(file_path):
        with open(file_path, 'r', encoding='utf-8') as file:
            content = file.read()
            # print(f'File: {file_name}\nContent:\n{content}\n{"=" * 20}\n')

            next = client.chat.completions.create(
                      model="gpt-3.5-turbo-16k",
                      messages=[
                        {
                          "role": "system",
                          "content": "IT 가이드 설명 웹 페이지 내용인데, 이 내용을 1000자 이내로 요약을 부탁해."
                        },
                        {
                          "role": "user",
                          "content": content
                        }
                      ],
                      temperature=0,
                      max_tokens=1200,
                      top_p=1,
                      frequency_penalty=0,
                      presence_penalty=0
                  )

            # 요약 결과를 DataFrame에 추가합니다.
            summary = next.choices[0].message.content
            df_results = pd.concat([df_results, pd.DataFrame({'file_name': [file_name], 'summary': [summary]})], ignore_index=True)

    time.sleep(3)

# %%
# 결과 DataFrame을 CSV 파일로 저장합니다.
df_results.to_csv('summaries.csv', index=False)
df_results.to_excel('summaries.xlsx', index=False)
